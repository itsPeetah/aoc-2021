# %%
import numpy as np

# %%
file = [line.strip() for line in open("puzzle5.txt").readlines()]

# %%
# class Line:
#     def __init__(self, line):
#         a,b = line.split(' -> ')
#         a = a.split(',')
#         b = b.split(',')
#         self.x1 = int(a[0])
#         self.y1 = int(a[1])
#         self.x2 = int(b[0])
#         self.y2 = int(b[1])
#         self.xMax = max(self.x1, self.x2)
#         self.xMin = min(self.x1, self.x2)
#         self.yMax = max(self.y1, self.y2)
#         self.yMin = min(self.y1, self.y1)
#     def isHorizontal(self): return self.y1 == self.y2
#     def isVertical(self): return self.x1 == self.x2
#     def __str__(self): return f"({self.x1},{self.y1}) -> ({self.x2},{self.y2})"
#     def __repr__(self): return self.__str__()

# %%
# allLines = [Line(dir) for dir in file]
# print("Total number of lines: ", len(allLines))
# hvLines = [line for line  in [Line(dir) for dir in file] if line.isHorizontal() or line.isVertical()]
# print("Number of horizontal or vertical lines:", len(hvLines))

# xMax = max(line.xMax for line in hvLines)
# xMin = min(line.xMin for line in hvLines)
# yMax = max(line.yMax for line in hvLines)
# yMin = min(line.yMin for line in hvLines)
# # (xMax, xMin, yMax, yMin)

# %%
# Out:
# [(590, 746),
#  (201, 413),
#  (61, 491),
#  (580, 580),
#  (680, 676),
#  (111, 339),
#  (521, 521),
#  (402, 402),
#  (841, 620),
#  (705, 705),
#  (546, 546),
#  (59, 59),
#  (97, 323),
#  (371, 801),
#  (620, 620),
#  (887, 457),
#  (754, 858),
#  (906, 327),
#  (619, 395),
#  (184, 184),
#  (874, 630),
#  (869, 799),
#  (897, 897),
#  (158, 158),
#  (280, 660),
#  (856, 856),
#  (164, 619),
#  (250, 250),
#  (750, 307),
#  (571, 323),
#  (192, 192),
#  (890, 988),
#  (321, 324),
#  (136, 22),
#  (317, 317),
#  (276, 276),
#  (198, 198),
#  (887, 685),
#  (209, 905),
#  (316, 195),
#  (283, 283),
#  (20, 983),
#  (627, 627),
#  (265, 265),
#  (291, 641),
#  (162, 11),
#  (289, 869),
#  (437, 224),
#  (735, 165),
#  (693, 693),
#  (243, 883),
#  (690, 269),
#  (240, 963),
#  (534, 534),
#  (756, 745),
#  (289, 190),
#  (328, 38),
#  (582, 582),
#  (491, 302),
#  (633, 633),
#  (146, 146),
#  (574, 574),
#  (87, 87),
#  (323, 601),
#  (969, 969),
#  (427, 267),
#  (884, 884),
# ...
